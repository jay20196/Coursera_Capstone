# %% [markdown]
# # Coursera Data Science CapStone Project
#
# The following notebook is made for the description of the Capstone project. It is part of the IBM Data Science Professional Certification.

# %% [markdown]
# ## Introduction
# | Description of the Problem and a discussion of the background
#
# Violent crimes, thefts, and robberies occur in majority of places. On daily basis, local businesses, houses etc encounter such crimes. Our job as data scientist is to analyze the pattern of crimes. study the distribution of types of crime that occur in various part of a particular place. It is important to know where the crimes are happening, usually areas with police stations farther in distance can result into increase crime count.
#
# In this case, I decided to perform statistical analysis and data science on the crimes in the city of chicago.
#
# We will also compare the location of local police station in the area, and their relation with the location of the crimes.

# %% [markdown]
# ## Data Understanding
# Descrption of Data and how it will be used to solve the problem.
#
# Here in this project, I will utilize the crime dataset & police stations provided by [Chicago Data Portal](https://data.cityofchicago.org/browse?category=Public+Safety&limitTo=datasets).
#
# Furthermore we will use the Foursquare API to fetch the venues to see in what specific type of environment or location does these crimes take place.
#
# ---
#
# ### Crime Data Set
# The crime data set consist of reported incidents of crime that occurred in the City of Chicago from 2018, The particular data set is subset of a bigger crime data with over 6.9 Million fields which would require greater computation power.. Data is extracted from the Chicago Police Department's CLEAR (Citizen Law Enforcement Analysis and Reporting) system. In order to protect the privacy of crime victims, addresses are shown at the block level only and specific locations are not identified
#
# The dataset consist of **22 fields** and over **226K rows**. The fields include attributes related to crime such as *Case number, block, IUCR codes, Description, Type of Crime, location, Lattitude, Longitude, district.*
#
# Since there are many fields that are not required in our analysis, we will require a lot of cleaning to do.

# %%
import pandas as pd
crime = pd.read_csv('https://data.cityofchicago.org/api/views/3i3m-jwuy/rows.csv?accessType=DOWNLOAD')

print("The Size of the data is: ",crime.shape)
crime.head(10)
# Out:
# The Size of the data is:  (266970, 30)
#          ID Case Number                    Date                   Block  IUCR  \
# 0  11556487    JC104662  12/31/2018 11:59:00 PM  112XX S SACRAMENTO AVE  1320
# 1  11561837    JC110056  12/31/2018 11:59:00 PM         013XX W 72ND ST  1153
# 2  11552699    JC100043  12/31/2018 11:57:00 PM     084XX S SANGAMON ST  1310
# 3  11552724    JC100006  12/31/2018 11:56:00 PM      018XX S ALLPORT ST  0440
# 4  11552731    JC100031  12/31/2018 11:55:00 PM     078XX S SANGAMON ST  0486
# 5  11552715    JC100026  12/31/2018 11:49:00 PM      052XX W GLADYS AVE  041A
# 6  11552741    JC100011  12/31/2018 11:48:00 PM       079XX S LAFLIN ST  0486
# 7  11552602    JC100089  12/31/2018 11:47:00 PM     018XX W BELMONT AVE  0460
# 8  11554852    JC101652  12/31/2018 11:45:00 PM   032XX W EVERGREEN AVE  1310
# 9  11553488    JC101094  12/31/2018 11:45:00 PM   032XX N SHEFFIELD AVE  0890
#
#          Primary Type                           Description  \
# 0     CRIMINAL DAMAGE                            TO VEHICLE
# 1  DECEPTIVE PRACTICE   FINANCIAL IDENTITY THEFT OVER $ 300
# 2     CRIMINAL DAMAGE                           TO PROPERTY
# 3             BATTERY  AGG: HANDS/FIST/FEET NO/MINOR INJURY
# 4             BATTERY               DOMESTIC BATTERY SIMPLE
# 5             BATTERY                   AGGRAVATED: HANDGUN
# 6             BATTERY               DOMESTIC BATTERY SIMPLE
# 7             BATTERY                                SIMPLE
# 8     CRIMINAL DAMAGE                           TO PROPERTY
# 9               THEFT                         FROM BUILDING
#
#                                 Location Description  Arrest  Domestic  \
# 0                                             STREET   False     False
# 1                                                NaN   False     False
# 2                                          APARTMENT   False     False
# 3                                              OTHER    True     False
# 4                                          APARTMENT   False     False
# 5                                             STREET   False     False
# 6                                          APARTMENT   False      True
# 7  VEHICLE - OTHER RIDE SHARE SERVICE (E.G., UBER...   False     False
# 8                                          APARTMENT   False     False
# 9                                      BAR OR TAVERN   False     False
#
#        ...       Longitude                       Location  \
# 0      ...      -87.696064  (41.689078832, -87.696064026)
# 1      ...      -87.657709  (41.763181359, -87.657709477)
# 2      ...      -87.647391  (41.740520866, -87.647390719)
# 3      ...      -87.657625  (41.857068095, -87.657625201)
# 4      ...      -87.647717   (41.75191443, -87.647716532)
# 5      ...      -87.760479   (41.87568438, -87.760479356)
# 6      ...      -87.661009  (41.750154295, -87.661008708)
# 7      ...      -87.673996   (41.939624824, -87.67399611)
# 8      ...      -87.707589  (41.905562114, -87.707588672)
# 9      ...      -87.654124    (41.940518859, -87.6541242)
#
#    Historical Wards 2003-2015  Zip Codes Community Areas  Census Tracts  \
# 0                        33.0     4447.0            73.0          256.0
# 1                        17.0    22257.0            65.0          408.0
# 2                        18.0    21554.0            70.0          530.0
# 3                         8.0    14920.0            33.0          365.0
# 4                        17.0    21554.0            70.0          487.0
# 5                        52.0    22216.0            26.0           68.0
# 6                        18.0    21554.0            70.0          558.0
# 7                        16.0     4449.0            46.0          648.0
# 8                        10.0     4299.0            24.0          455.0
# 9                        38.0     4449.0            57.0          731.0
#
#    Wards  Boundaries - ZIP Codes Police Districts  Police Beats
# 0   42.0                    33.0              9.0         254.0
# 1   32.0                    23.0             17.0         216.0
# 2   13.0                    59.0             20.0         233.0
# 3   26.0                    43.0             15.0         150.0
# 4   31.0                    59.0             20.0         229.0
# 5    7.0                    32.0             25.0          97.0
# 6   31.0                    59.0             20.0         230.0
# 7   40.0                    22.0              5.0         172.0
# 8   49.0                     5.0              7.0         190.0
# 9   25.0                    22.0              5.0          28.0
#
# [10 rows x 30 columns]

# %% [markdown]
# ### Police Department
# The police department contains of **15 attributes**, each with various location of the police station.

# %%
police_station = pd.read_csv('https://data.cityofchicago.org/api/views/z8bn-74gv/rows.csv?accessType=DOWNLOAD')
print("The Size of the data is: ",police_station.shape)
police_station.head(10)
# Out:
#   DISTRICT   DISTRICT NAME                   ADDRESS     CITY STATE    ZIP  \
# 0        1         Central           1718 S State St  Chicago    IL  60616
# 1        2       Wentworth      5101 S Wentworth Ave  Chicago    IL  60609
# 2        3  Grand Crossing  7040 S Cottage Grove Ave  Chicago    IL  60637
# 3        4   South Chicago           2255 E 103rd St  Chicago    IL  60617
# 4        5         Calumet            727 E 111th St  Chicago    IL  60628
# 5        6         Gresham         7808 S Halsted St  Chicago    IL  60620
# 6        7       Englewood            1438 W 63rd St  Chicago    IL  60636
# 7        8    Chicago Lawn            3420 W 63rd St  Chicago    IL  60629
# 8        9         Deering         3120 S Halsted St  Chicago    IL  60608
# 9       10           Ogden          3315 W Ogden Ave  Chicago    IL  60623
#
#                                              WEBSITE         PHONE  \
# 0  http://home.chicagopolice.org/community/distri...  312-745-4290
# 1  http://home.chicagopolice.org/community/distri...  312-747-8366
# 2  http://home.chicagopolice.org/community/distri...  312-747-8201
# 3  http://home.chicagopolice.org/community/distri...  312-747-7581
# 4  http://home.chicagopolice.org/community/distri...  312-747-8210
# 5  http://home.chicagopolice.org/community/distri...  312-745-3617
# 6  http://home.chicagopolice.org/community/distri...  312-747-8223
# 7  http://home.chicagopolice.org/community/distri...  312-747-8730
# 8  http://home.chicagopolice.org/community/distri...  312-747-8227
# 9  http://home.chicagopolice.org/community/distri...  312-747-7511
#
#             FAX           TTY  X COORDINATE  Y COORDINATE   LATITUDE  \
# 0  312-745-3694  312-745-3693   1176569.052   1891771.704  41.858373
# 1  312-747-5396  312-747-6656   1175864.837   1871153.753  41.801811
# 2  312-747-5479  312-747-9168   1182739.183   1858317.732  41.766431
# 3  312-747-5276  312-747-9169   1193131.299   1837090.265  41.707933
# 4  312-747-5935  312-747-9170   1183305.427   1831462.313  41.692723
# 5  312-745-3649  312-745-3639   1172283.013   1853022.646  41.752137
# 6  312-747-6558  312-747-6652   1167659.235   1863005.522  41.779632
# 7  312-747-8545  312-747-8116   1154575.242   1862672.049  41.778987
# 8  312-747-5329  312-747-9172   1171440.240   1884085.224  41.837394
# 9  312-747-7429  312-747-7471   1154500.753   1890985.501  41.856685
#
#    LONGITUDE                         LOCATION
# 0 -87.627356   (41.8583725929, -87.627356171)
# 1 -87.630560  (41.8018110912, -87.6305601801)
# 2 -87.605748  (41.7664308925, -87.6057478606)
# 3 -87.568349  (41.7079332906, -87.5683491228)
# 4 -87.604506  (41.6927233639, -87.6045058667)
# 5 -87.644229  (41.7521368378, -87.6442289066)
# 6 -87.660887  (41.7796315359, -87.6608870173)
# 7 -87.708864   (41.778987189, -87.7088638153)
# 8 -87.646408  (41.8373944311, -87.6464077068)
# 9 -87.708382   (41.8566845327, -87.708381958)

# %% [markdown]
# I believe that having greater number of can enable for complex datascience such as densitiy based clustering and segmentation.
